# %% [markdown]
# <a href="https://colab.research.google.com/github/Eliandry/Neural-networks/blob/main/vgg16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist    
from tensorflow import keras
from google.colab import files
from io import BytesIO
from PIL import Image
from keras.preprocessing import image as kp_image

# %%
model=keras.applications.VGG16()
# Out:
# ...
# 553467904/553467096 [==============================] - 3s 0us/step

# %%
uploaded=files.upload()
img = Image.open(BytesIO(uploaded['f.jpg']))
img = img.resize((224, 224), Image.ANTIALIAS)
img.save('f.jpg')
# Out:
#      <input type="file" id="files-cf5b0929-6788-4587-af9d-81068aa1ad2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf5b0929-6788-4587-af9d-81068aa1ad2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving f.jpg to f (2).jpg

# %%
plt.imshow(img)

# %%
img=np.array(img)
x=keras.applications.vgg16.preprocess_input(img)
print(x.shape)
x=np.expand_dims(x,axis=0)
# Out:
# (224, 224, 3)

# %%
res=model.predict(x)
print(np.argmax(res))
# Out:
# 937

# %%
https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a#file-imagenet1000_clsidx_to_labels-txt
